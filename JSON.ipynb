# %% [markdown]
# <a href="https://colab.research.google.com/github/lynn-rotich/git_practice/blob/main/JSON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import libraries
import json

with open("MOCK_DATA.json") as f:
  data = json.load(f)

type(data)
# Out:
# list

# %%
# convert to dataframe

import pandas as pd

new_data = pd.DataFrame(data)
new_data.head()
# Out:
#    id  first_name last_name                    email  gender  car year  \
# 0   1  Rutherford     Bruce             rbruce0@g.co    Male      2012
# 1   2   Benedicta  Todarini       btodarini1@php.net  Female      1993
# 2   3      Kylila      Sant      ksant2@hatena.ne.jp  Female      1997
# 3   4       Aymer   Stallen  astallen3@blinklist.com    Male      2010
# 4   5       Minny     Agate    magate4@hostgator.com  Female      2001
#
#          date        car
# 0    4/2/2025   Infiniti
# 1  10/28/2024  Chevrolet
# 2   7/31/2024      Buick
# 3   4/28/2025     Nissan
# 4   3/26/2025     Toyota

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1000 non-null   int64
#  1   first_name  1000 non-null   object
#  2   last_name   1000 non-null   object
#  3   email       1000 non-null   object
#  4   gender      1000 non-null   object
#  5   car year    1000 non-null   int64
#  6   date        960 non-null    object
#  7   car         968 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 62.6+ KB

# %% [markdown]
# ## Data Cleaning
#
# What makes data dirty?
# - Missing values
# - Outliers

# %% [markdown]
# How to deal with missing values
#
# - Fill the missing{mean or mode},
